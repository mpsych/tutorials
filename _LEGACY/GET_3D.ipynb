# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.insert(0,'../..')

# %%
import omama as O

# %%
omama_loader = O.OmamaLoader()

# %%
data = O.Data(omama_loader, load_cache=True)

# %%
imgs3d = O.DataHelper.get3D(N=1, timing=True)
# Out:
# get3D                    ...took    28.766679 seconds

# %%
O.DataHelper.view(imgs3d[0])

# %%
imgs3d[0].pixels.size
# Out:
# 465896340

# %%
imgs2d = O.DataHelper.get2D(N=5, timing=True)
# Out:
# get2D                    ...took     3.086143 seconds

# %%
O.DataHelper.view(imgs2d[2])
